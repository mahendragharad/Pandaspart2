# %%
pandas is used for data loading opeartion , data manipulation operation , statistical analysis , data visualisation

# %%
import pandas as p

# %%
p.read_csv('addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
data = p.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# How to know the data types of the all columns
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# It is gives us the little bit statistical analysis of the data 
data.describe()
# Describe() gives us the info about only integer data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# step by step approch to figure out the categorical datasets 
# The way to figure out info about the categoriacl data set 
data[['Name' , 'Sex' , 'Ticket' , 'Embarked' , 'Cabin' ]].describe()
# Out:
#                            Name   Sex  Ticket Embarked    Cabin
# count                       891   891     891      889      204
# unique                      891     2     681        3      147
# top     Braund, Mr. Owen Harris  male  347082        S  B96 B98
# freq                          1   577       7      644        4

# %%
# Another way to figure out categorical data set 

data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# Fetching the floating point numbers data sets 

data.dtypes == 'float'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[data.dtypes == 'float'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
data[data.dtypes[data.dtypes == 'float'].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
data[(data['Survived'] == 0) & (data['Sex'] == 'male') ]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[(data['Survived'] == 0) & (data['Sex'] == 'male') ].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(data[(data['Survived'] == 0) & (data['Sex'] == 'male') ])
# Out:
# 468

# %%
len(data[(data['Survived'] == 0) & (data['Sex'] == 'female') ])
# Out:
# 81

# %%
# 'value_counts is the gruop by function'
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(data[data['Sex'] == 'male'])
# Out:
# 577

# %%
len(data[data['Sex'] == 'female'])
# Out:
# 314

# %%
len(data[(data['Survived'] == 1) & (data['Sex'] == 'male') ])
# Out:
# 109

# %%
len(data[(data['Survived'] == 1) & (data['Sex'] == 'female') ])
# Out:
# 233

# %%
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(data['Fare'])
# Out:
# 512.3292

# %%
data['Fare'] == max(data['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
data[data['Fare'] == max(data['Fare'])][['Name']]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
data[data['Fare'] == max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
data[data['Fare'] == min(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# searching for people who get cabin 
data[data['Cabin'].isnull() == False ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data['Cabin'].isnull() == False ])
# Out:
# 204

# %%
Creating new column inside the dataset

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['New_col'] = 'Mahendra_gharad'

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# How to create duplicate column

# %%
data['New_col'] = data['Name']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Creating a column with addition of Pclass column and Age column

# %%
data['New_ADD_class'] = data['Age'] + data['Pclass']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Important note = Axis 0 = 'ROw' and Axis 1 = column
because of this reason below code giving us error 
"['New_col'] not found in axis"
because it is trying to find the column in row becoz when we use drop statement 
axis by default set to 0

# %%
# How to delete the column 
data.drop("New_col")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21988\554910430.py in <module>
#       1 # How to delete the column
# ----> 2 data.drop("New_col")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
To perform above query we have to set axis = 1 let's try this

# %%
# How to delete the column 
data.drop("New_col" , axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# But the above query has not deleted the column permently
# becoz of inplace function 

if inplace = False it means it is not permenant 
if inplace = True means it is perment 

To make the above chnages permenant we have to set the inplace = True

There are two ways to make changes permenant 

1. data = data.drop("New_col" , axis = 1)
2. data.drop("New_col" , axis = 1 , inplace = True )

# %%
data.drop("New_col" , axis = 1 , inplace = True )

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Now we see theb operations on the row :

# %%
data.drop(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(0 , inplace = True )

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Accssing rows 
data.head(1)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked  New_ADD_class
# 1      0  PC 17599  71.2833   C85        C           39.0

# %%
iloc = index location

# %%
data.iloc[0]
# Out:
# PassengerId                                                      2
# Survived                                                         1
# Pclass                                                           1
# Name             Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                         female
# Age                                                           38.0
# SibSp                                                            1
# Parch                                                            0
# Ticket                                                    PC 17599
# Fare                                                       71.2833
# Cabin                                                          C85
# Embarked                                                         C
# New_ADD_class                                                 39.0
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# PassengerId                                                      2
# Survived                                                         1
# Pclass                                                           1
# Name             Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                         female
# Age                                                           38.0
# SibSp                                                            1
# Parch                                                            0
# Ticket                                                    PC 17599
# Fare                                                       71.2833
# Cabin                                                          C85
# Embarked                                                         C
# New_ADD_class                                                 39.0
# Name: 1, dtype: object

# %%
iloc goes with the internal indexing even we deleted the row it by 
default set indexing internally from zero 

iloc always takes internal indexes

# %%
loc goes with the indexes which are assigned to the records

loc always takes named indexes

# %%
# slicing with datasets 
data.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  New_ADD_class
# 2  STON/O2. 3101282   7.9250   NaN        S           29.0
# 3            113803  53.1000  C123        S           36.0
# 4            373450   8.0500   NaN        S           38.0
# 5            330877   8.4583   NaN        Q            NaN

# %%
# accessing perticular columns 
data.loc[101:106 , ['Survived' ,'Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
data.loc[[3,4] , ['Fare' , 'Cabin' , 'Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.loc[3:4 , ['Fare' , 'Cabin' , 'Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
# using iloc 
# we have to use indexes instead of rows names to find records
data.iloc[2:4 , [9,10,11]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.loc[ : , ['PassengerId' , 'Survived' , 'Pclass' ]]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [890 rows x 3 columns]

# %%
data.iloc[ : , [0,1,2]]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [890 rows x 3 columns]

# %%
data[['PassengerId' , 'Survived' , 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [890 rows x 3 columns]

# %%
data.loc[[3,5] , ['PassengerId', 'Survived' , 'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data[(data['Age'] > 35 )]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2 = data.iloc[1:5,[2,3,4,5,6,7,8,9,10]]

# %%
data2
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0      0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4       3                      Allen, Mr. William Henry    male  35.0      0
# 5       3                              Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin
# 2      0  STON/O2. 3101282   7.9250   NaN
# 3      0            113803  53.1000  C123
# 4      0            373450   8.0500   NaN
# 5      0            330877   8.4583   NaN

# %%
data2.columns
# Out:
# Index(['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin'],
#       dtype='object')

# %%
data2.set_index('Name')
# But it is not going to change it permenantly
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
# Setting the indexes names as per our reqiurements 
#  to make changes permenant 
data2.set_index('Name' , inplace = True)

# %%
data2
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
# To dropp null records 
# In it axis by default = 0 
#  dropna will check the null values and then it perform drop operation 
data2.dropna()
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
#
#                                               Parch  Ticket  Fare Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  113803  53.1  C123

# %%
data2.dropna( axis = 1 )
# Out:
#                                               Pclass     Sex  SibSp  Parch  \
# Name
# Heikkinen, Miss. Laina                             3  female      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female      1      0
# Allen, Mr. William Henry                           3    male      0      0
# Moran, Mr. James                                   3    male      0      0
#
#                                                         Ticket     Fare
# Name
# Heikkinen, Miss. Laina                        STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803  53.1000
# Allen, Mr. William Henry                                373450   8.0500
# Moran, Mr. James                                        330877   8.4583

# %%
data2
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
data2.dropna(axis = 1 , thresh = 1)
# if the condition is satisfy then thresh perform its operation
# It perform it operation of basis of nonNAn values
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
data2.dropna(axis = 1 , thresh = 2 )
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket     Fare
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803  53.1000
# Allen, Mr. William Henry                          0            373450   8.0500
# Moran, Mr. James                                  0            330877   8.4583

# %%
data2.dropna(axis = 1 , thresh = 3 )
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket     Fare
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803  53.1000
# Allen, Mr. William Henry                          0            373450   8.0500
# Moran, Mr. James                                  0            330877   8.4583

# %%
# To fill NaN values ]
data2.fillna('mahendra')
# Out:
#                                               Pclass     Sex       Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female      26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female      35.0      1
# Allen, Mr. William Henry                           3    male      35.0      0
# Moran, Mr. James                                   3    male  mahendra      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare     Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250  mahendra
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000      C123
# ...

# %%
# Just replacing the age with the mean() values 
data2.fillna(data2['Age'].mean())
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male  32.0      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250  32.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
data2.groupby('Sex').count()
# Out:
#         Pclass  Age  SibSp  Parch  Ticket  Fare  Cabin
# Sex
# female       2    2      2      2       2     2      1
# male         2    1      2      2       2     2      0

# %%
# Find the average ages of males and females 
data2.groupby('Sex').mean()
# Out:
#         Pclass   Age  SibSp  Parch      Fare
# Sex
# female     2.0  30.5    0.5    0.0  30.51250
# male       3.0  35.0    0.0    0.0   8.25415

# %%
data2.groupby('Sex').mean()['Age']
# Out:
# Sex
# female    30.5
# male      35.0
# Name: Age, dtype: float64

# %%
# Find total revenue generated by the males and females 

data2.groupby('Sex').sum()['Fare']
# Out:
# Sex
# female    61.0250
# male      16.5083
# Name: Fare, dtype: float64

# %%
data3 = data.iloc[ 0:4 , 0:5]

# %%
data2
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
data3
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
#  How to concatanate the two tables 
# It perform a row wise concatanation becoz axis = 0 
p.concat([data2 , data3])
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Heikkinen, Miss. Laina                             3  female  26.0    0.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0    1.0
# Allen, Mr. William Henry                           3    male  35.0    0.0
# Moran, Mr. James                                   3    male   NaN    0.0
# 1                                                  1  female   NaN    NaN
# 2                                                  3  female   NaN    NaN
# 3                                                  1  female   NaN    NaN
# 4                                                  3    male   NaN    NaN
#
#                                               Parch            Ticket  \
# Heikkinen, Miss. Laina                          0.0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    0.0            113803
# Allen, Mr. William Henry                        0.0            373450
# ...

# %%
#  After setting axis = 1 
# It joined both tables in the vertical format 
p.concat([data2 , data3] , axis = 1 )
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Heikkinen, Miss. Laina                           3.0  female  26.0    0.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)     1.0  female  35.0    1.0
# Allen, Mr. William Henry                         3.0    male  35.0    0.0
# Moran, Mr. James                                 3.0    male   NaN    0.0
# 1                                                NaN     NaN   NaN    NaN
# 2                                                NaN     NaN   NaN    NaN
# 3                                                NaN     NaN   NaN    NaN
# 4                                                NaN     NaN   NaN    NaN
#
#                                               Parch            Ticket  \
# Heikkinen, Miss. Laina                          0.0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)    0.0            113803
# Allen, Mr. William Henry                        0.0            373450
# ...

# %%
data2
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# ...

# %%
#  We have to divide the Pclass values by 3 and store that values in 
# in the Pclass 

data2['New_col2'] = data2['Pclass'].apply(lambda x : x/3)
#  WE can aslo acheive this by using external function as below

# %%
data2
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin  New_col2
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123  0.333333
# ...

# %%
def func1(x) :
    return x/3

# %%
data2['New_col3'] = data2['Pclass'].apply(func1)

# %%
data2
# Out:
#                                               Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0      1
# Allen, Mr. William Henry                           3    male  35.0      0
# Moran, Mr. James                                   3    male   NaN      0
#
#                                               Parch            Ticket  \
# Name
# Heikkinen, Miss. Laina                            0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            113803
# Allen, Mr. William Henry                          0            373450
# Moran, Mr. James                                  0            330877
#
#                                                  Fare Cabin  New_col2  \
# Name
# Heikkinen, Miss. Laina                         7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123  0.333333
# ...

# %%
#  How to calculate the total length of the names present in names column
data3['Length_of_names'] = data3['Name'].apply(len)

# %%
data3
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Length_of_names
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female               51
# 2                             Heikkinen, Miss. Laina  female               22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female               44
# 4                           Allen, Mr. William Henry    male               24

# %%
question : where ever in the dataset 
PassengerId is less than 3 keep is as it is but if it is greater than 3
then try to update it with its logarithmic value

# %%
import math 
def log(x) :
    if x < 3 :
        return 3 
    else :
        return math.log10(x)

# %%
data3['logarithmic_values'] = data3['PassengerId'].apply(log)

# %%
data3
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Length_of_names  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female         3.000000
# 2                             Heikkinen, Miss. Laina  female         0.477121
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female         0.602060
# 4                           Allen, Mr. William Henry    male         0.698970
#
#    logarithmic_values
# 1            3.000000
# 2            0.477121
# 3            0.602060
# 4            0.698970

# %%
def test3(x) :
    if x == 'female' :
        return 1 
    else :
        return 0

# %%
data3['New_F_M'] = data3['Sex'].apply(test3)

# %%
data3
# Out:
#    PassengerId  Survived  Pclass  \
# 1     3.000000         1       1
# 2     0.477121         1       3
# 3     0.602060         1       1
# 4     0.698970         0       3
#
#                                                 Name     Sex  Length_of_names  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female         3.000000
# 2                             Heikkinen, Miss. Laina  female         0.477121
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female         0.602060
# 4                           Allen, Mr. William Henry    male         0.698970
#
#    logarithmic_values  New_F_M
# 1            3.000000        1
# 2            0.477121        1
# 3            0.602060        1
# 4            0.698970        0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Question if else based 
0-100  - 'A'
101 - 199 - 'B"
200+ - 'C"

# %%
def test4(x) :
    if x <= 100 :
        return "A"
    elif x > 100 and x < 200 :
        return "B"
    else :
        return "C"

# %%
data['Fare_Marking'] = data['Fare'].apply(test4)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...
